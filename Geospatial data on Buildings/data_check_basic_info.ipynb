# %% [markdown]
# When I collect external data while working on analytics,
# I go through the following process:
#
# 1. Look at the provided data specifications and check the following first
#    - Whether it can be used without the risk of copyright infringement
#    - Whether the raw data has the columns I need
#    - Is it possible to convert raw data into meaningful information by cleaning and processing it?
#
# 2. If it is determined that the data is usable, the data is downloaded.
#    Then, it is checked whether the raw data is configured according to the provided data specifications.
#    In my experience, open public data often do not match specifications.
#    So, in order to determine whether the data is correct and complete, check the following with Python code.
#    - column name
#    - data type
#    - Existence of missing values
#    - Whether a specific column is made up of unique values
#    - Examples of data values

# %%
import pandas as pd
import numpy as np
import geopandas as gpd

# %% [markdown]
# ### Read shp file (raw data)
# - data name : "건축물연령공간정보" - 부산광역시 중구
# - data source : The National Spatial Information Portal (http://openapi.nsdi.go.kr/nsdi/index.do)

# %%
df = gpd.read_file('data/국가공간정보포털_건축물연령정보_부산중구/AL_26110_D196_20230111.shp',
                   sep = ",", encoding='cp949')
print(df.shape)
# Out:
# (6536, 32)

# %% [markdown]
# ### Check and change column name (refer to data specification)

# %%
# Read excel file (data specification)

df_col = pd.read_excel('data/datasetDetail.xlsx')
print(df_col.shape)
# Out:
# (31, 2)

# %%
# Create dictionary type data with column code as key and column name as value

a = df_col.set_index('col_name_code').to_dict()
a.get('col_name')
# Out:
# {'A0': '도형ID',
#  'A1': 'GIS건물통합식별번호',
#  'A2': '고유번호',
#  'A3': '법정동코드',
#  'A4': '법정동명',
#  'A5': '특수지구분코드',
#  'A6': '특수지구분명',
#  'A7': '지번',
#  'A8': '건물식별번호',
#  'A9': '집합건물구분코드',
#  'A10': '집합건물구분',
#  'A11': '대장종류코드',
#  'A12': '대장종류',
#  'A13': '건물명',
#  'A14': '건물동명',
#  'A15': '건물연면적',
#  'A16': '건축물구조코드',
#  'A17': '건축물구조명',
#  'A18': '주요용도코드',
#  'A19': '주요용도명',
#  'A20': '건물높이',
#  'A21': '지상층수',
#  'A22': '지하층수',
#  'A23': '허가일자',
#  'A24': '사용승인일자',
#  'A25': '건물연령',
#  'A26': '연령대구분코드',
#  'A27': '연령대구분명',
#  'A28': '연령대5계급코드',
#  'A29': '연령대5계급명',
#  'A30': '데이터기준일자'}

# %%
# Change raw data column name using this dictionary

df.rename(columns = a.get('col_name'), inplace=True)

# %% [markdown]
# ### Several ways to check basic information such as the number of missing values and data type.
# 1. df.info()
# 2. df.describe()
# 3. self-made code

# %% [markdown]
# #### 1. df.info()

# %%
df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 6536 entries, 0 to 6535
# Data columns (total 32 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   도형ID         6536 non-null   int64
#  1   GIS건물통합식별번호  6536 non-null   object
#  2   고유번호         6536 non-null   object
#  3   법정동코드        6536 non-null   object
#  4   법정동명         6536 non-null   object
#  5   특수지구분코드      6536 non-null   object
#  6   특수지구분명       6536 non-null   object
#  7   지번           6536 non-null   object
#  8   건물식별번호       6536 non-null   object
#  9   집합건물구분코드     6536 non-null   object
#  10  집합건물구분       6536 non-null   object
#  11  대장종류코드       6536 non-null   object
#  12  대장종류         6536 non-null   object
#  13  건물명          768 non-null    object
#  14  건물동명         350 non-null    object
#  15  건물연면적        6536 non-null   float64
#  16  건축물구조코드      6536 non-null   object
#  17  건축물구조명       6534 non-null   object
#  18  주요용도코드       6535 non-null   object
#  19  주요용도명        6535 non-null   object
#  20  건물높이         6533 non-null   float64
#  21  지상층수         6536 non-null   int64
#  22  지하층수         6518 non-null   float64
#  23  허가일자         4015 non-null   object
#  24  사용승인일자       4448 non-null   object
#  25  건물연령         4448 non-null   float64
#  26  연령대구분코드      6536 non-null   object
#  27  연령대구분명       6536 non-null   object
#  28  연령대5계급코드     6536 non-null   object
#  29  연령대5계급명      6536 non-null   object
#  30  데이터기준일자      6536 non-null   object
#  31  geometry     6536 non-null   geometry
# dtypes: float64(4), geometry(1), int64(2), object(25)
# memory usage: 1.6+ MB

# %% [markdown]
# #### 2. df.describe()

# %%
df.describe()
# Out:
#                도형ID         건물연면적         건물높이         지상층수         지하층수  \
# count  6.536000e+03   6536.000000  6533.000000  6536.000000  6518.000000
# mean   6.180763e+07    589.936258     5.753874     3.358170     0.331697
# std    2.230548e+03   1902.859245     9.658369     2.290211     0.565065
# min    6.180366e+07      0.000000     0.000000     0.000000     0.000000
# 25%    6.180568e+07     83.865000     0.000000     2.000000     0.000000
# 50%    6.180768e+07    179.275000     0.000000     3.000000     0.000000
# 75%    6.180958e+07    453.370000    11.350000     4.000000     1.000000
# max    6.181140e+07  40348.180000   115.880000    33.000000     7.000000
#
#               건물연령
# count  4448.000000
# mean     33.597572
# std      13.174698
# min       2.000000
# 25%      26.000000
# 50%      34.000000
# 75%      45.000000
# max      88.000000

# %%
df.describe(include='O')
# Out:
#                          GIS건물통합식별번호                 고유번호       법정동코드  \
# count                           6536                 6536        6536
# unique                          6535                 6293          40
# top     2018203345041779409000000000  2611012000100410331  2611010100
# freq                               2                   17        1339
#
#                 법정동명 특수지구분코드 특수지구분명    지번     건물식별번호 집합건물구분코드 집합건물구분  ...  \
# count           6536    6536   6536  6536       6536     6536   6536  ...
# unique            40       2      2  4079       6521        2      2  ...
# top     부산광역시 중구 영주동       1     일반  11-1  100171006        1  일반건축물  ...
# freq            1339    6524   6524    17          2     5541   5541  ...
#
#           건축물구조명 주요용도코드 주요용도명        허가일자      사용승인일자 연령대구분코드 연령대구분명 연령대5계급코드  \
# count       6534   6535  6535        4015        4448    6536   6536     6536
# unique        13     26    25        2869        3047      10     10       19
# top     철근콘크리트구조  01000  단독주택  1975-06-27  1975-09-15      ZZ     기타      ZZZ
# freq        3462   2928  2928          69          85    2088   2088     2088
#
#        연령대5계급명     데이터기준일자
# count     6536        6536
# unique      19           1
# top        구분없  2023-01-11
# freq      2088        6536
#
# [4 rows x 25 columns]

# %% [markdown]
# #### 3. self-made code

# %%
col_list = list(df.columns.values)

info_list = []
for i in col_list:
    if df[i].nunique()>10:
        a = df[i].unique()[0]
    else:
        a = df[i].unique()
    info_list_a = [i, df[i].dtype, df[i].isnull().sum(), df[i].notnull().sum(), df[i].nunique(), a]
    info_list.append(info_list_a)

df_info = pd.DataFrame(data = info_list, 
                       columns = ['col_name','dtype','isnull_sum','notnull_sum','nunique','ex'])

# %%
df_info
# Out:
#        col_name     dtype  isnull_sum  notnull_sum  nunique  \
# 0          도형ID     int64           0         6536     6536
# 1   GIS건물통합식별번호    object           0         6536     6535
# 2          고유번호    object           0         6536     6293
# 3         법정동코드    object           0         6536       40
# 4          법정동명    object           0         6536       40
# 5       특수지구분코드    object           0         6536        2
# 6        특수지구분명    object           0         6536        2
# 7            지번    object           0         6536     4079
# 8        건물식별번호    object           0         6536     6521
# 9      집합건물구분코드    object           0         6536        2
# 10       집합건물구분    object           0         6536        2
# 11       대장종류코드    object           0         6536        2
# 12         대장종류    object           0         6536        2
# 13          건물명    object        5768          768      703
# 14         건물동명    object        6186          350      190
# 15        건물연면적   float64           0         6536     5693
# 16      건축물구조코드    object           0         6536       15
# 17       건축물구조명    object           2         6534       13
# 18       주요용도코드    object           1         6535       26
# 19        주요용도명    object           1         6535       25
# 20         건물높이   float64           3         6533      589
# 21         지상층수     int64           0         6536       27
# 22         지하층수   float64          18         6518        8
# 23         허가일자    object        2521         4015     2869
# 24       사용승인일자    object        2088         4448     3047
# 25         건물연령   float64        2088         4448       70
# 26      연령대구분코드    object           0         6536       10
# 27       연령대구분명    object           0         6536       10
# 28     연령대5계급코드    object           0         6536       19
# 29      연령대5계급명    object           0         6536       19
# 30      데이터기준일자    object           0         6536        1
# 31     geometry  geometry           0         6536     6535
#
#                                                    ex
# 0                                            61803665
# 1                        1988202940501795945100000000
# 2                                 2611010100100010092
# 3                                          2611010100
# 4                                        부산광역시 중구 영주동
# 5                                              [1, 2]
# 6                                             [일반, 산]
# 7                                                1-92
# 8                                                2376
# 9                                              [2, 1]
# 10                                     [집합건축물, 일반건축물]
# 11                                             [3, 2]
# 12                                     [표제부, 일반건축물대방]
# 13                                               None
# 14                                               None
# 15                                           5041.344
# 16                                                 21
# 17                                           철근콘크리트구조
# 18                                              02000
# 19                                               공동주택
# 20                                                0.0
# 21                                                  6
# 22      [1.0, 0.0, 2.0, nan, 3.0, 5.0, 4.0, 6.0, 7.0]
# 23                                         1988-04-07
# 24                                         1988-12-26
# 25                                               36.0
# 26           [04, 05, ZZ, 02, 06, 08, 03, 01, 09, 07]
# 27  [30대, 40대, 기타, 10대, 50대, 70대, 20대, 10세미만, 80대,...
# 28                                                040
# 29                                              40세미만
# 30                                       [2023-01-11]
# 31  POLYGON ((385247.1157 181518.3571, 385274.9499...
